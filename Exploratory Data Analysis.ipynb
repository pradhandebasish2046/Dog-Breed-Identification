# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from scipy import stats

# %%
len(os.listdir('train'))
# Out:
# 10222

# %%
df_labels = pd.read_csv("labels.csv")
train_file = 'train/'
test_file = 'test/'

# %%
df_labels.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
df_labels.shape
# Out:
# (10222, 2)

# %%
print(len(os.listdir(test_file)))
# Out:
# 10357

# %%
directory = 'train/'+df_labels['id'].iloc[0]+'.jpg'
from IPython.display import Image
Image(filename=directory)

# %%
df = pd.DataFrame(df_labels['breed'].value_counts())

# %%
df_labels["breed"].value_counts()
# Out:
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
#                        ...
# golden_retriever         67
# brabancon_griffon        67
# komondor                 67
# eskimo_dog               66
# briard                   66
# Name: breed, Length: 120, dtype: int64

# %%
df_labels["breed"].value_counts().plot.bar(figsize=(20, 10));
plt.savefig('eda.jpg')

# %%
df_labels.isnull().values.any()
# Out:
# False

# %%
id1,id2,id3 = df_labels['id'].iloc[340],df_labels['id'].iloc[1000],df_labels['id'].iloc[2550]
img1,img2,img3 = 'train/'+id1+'.jpg','train/'+id2+'.jpg','train/'+id3+'.jpg'
img_1 = Image.open(img1)
img_2 = Image.open(img2)
img_3 = Image.open(img3)
print(img_1.size)
print(img_2.size)
print(img_3.size)
# Out:
# (250, 309)
# (500, 375)
# (661, 532)

# %%
print(stats.describe(df_labels.value_counts('breed')))
# Out:
# DescribeResult(nobs=120, minmax=(66, 126), mean=85.18333333333334, variance=176.840056022409, skewness=0.8743357746842151, kurtosis=0.09128127243258932)

# %% [markdown]
# # Key Takeaways From EDA

# %% [markdown]
# 1. There are total 10222 number of training images and 10357 test images are present
# 2. Out of 10222 training images total 120 different dog breeds are present
# 3. All the breeds gets different no of images. 126 is the maximum number for any single class dog breed whose class name is scottish_deerhound. Breed Briard and Eskimo_dog gets the minimum number of images whose value is 66
# 4. There is no Null values are present
# 5. One of the most important thing to notice is different images gets different size
